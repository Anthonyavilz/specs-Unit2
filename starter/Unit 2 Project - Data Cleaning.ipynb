# %% [markdown]
# # Unit 2 Project - Data Cleaning

# %% [markdown]
# ## Part 1: Prepare Environment and Jupyter Notebook

# %% [markdown]
# ### Step 1: Create Virtual Environment
#
# This step should have been completed prior to opening the Jupyter Notebook. Refer to project instructions.

# %% [markdown]
# ### Step 2: Open Jupyter Notebook File
#
# Congratulations! If you're here it means you have completed Step 2.

# %% [markdown]
# ### Step 3: Load .csv Files into DataFrames

# %%
####### TO DO ########
import pandas as pd

houses_df = pd.read_csv('house_data.csv')
house_sales_df = pd.read_csv('house_sales.csv')

# load house_data.csv into a dataframe using pd.read_csv()

# load house_sales.csv into a dataframe using pd.read_csv()

######################

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was loaded succussfully
#houses_df.head()
houses_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was loaded succussfully
#house_sales_df.head()
house_sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB

# %% [markdown]
# ### Step 4: Create Data Dictionaries for Each Dataset

# %%
####### TO DO ###########

# Work in the cells below to fill in missing information in the data dictionary.

# %% [markdown]
# #### Data Dictionary - House Data
#
# **id**:
# > Description: Unique ID of the house
# >
# > Data type: Int64
#
# **bedrooms**:
# > Description: Number of bedrooms the house has
# >
# > Data type: Int64
#
# **bathrooms**:
# > Description: Number of bathrooms the house has
# >
# > Data type: Float64
#
# **sqft_living**:
# > Description: Square footage of the actual livable space in the home
# >
# > Data type: Int64
#
# **sqft_lot**:
# > Description: Square footage of the lot the house sits on
# >
# > Data type: Float64
#
# **floors**:
# > Description: Number of floors the house has
# >
# > Data type: Float64
#
# **waterfront**:
# > Description: Whether or not the house is a waterfront property
# >
# > Data type: Object
#
# **view**:
# > Description: How good of a view the house has
# >
# > Data type: Object
#
# **condition**:
# > Description: How well the condition of the home is
# >
# > Data type: Object
#
# **grade**:
# > Description: Numberical scale 1-13 of how the house is
# >
# > Data type: Float64
#
# **sqft_above**:
# > Description: Sqft of the house above ground
# >
# > Data type: Float64
#
# **sqft_basement**:
# > Description: Sqft of the basement if the house has one
# >
# > Data type: Int64
#
# **yr_built**:
# > Description: The year the house was built in
# >
# > Data type: Float64
#
# **yr_renovated**:
# > Description: The year the house was renovated if it was
# >
# > Data type: Float64
#
# **zipcode**:
# > Description: Zipcode the house is in
# >
# > Data type: Float64
#
# **lat**:
# > Description: Latitude of the house
# >
# > Data type: Float64
#
# **long**:
# > Description: Longitude of the house
# >
# > Data type: Float64
#
# **sqft_living15**:
# > Description: Sqft of the living space of the 15 nearest neighbors
# >
# > Data type: Int64
#
# **sqft_lot15**:
# > Description: Sqft of the lot space of the 15 nearest neighbors
# >
# > Data type: Int64

# %% [markdown]
# #### Data Dictionary - House Sales Data
#
# **id**:
# > Description: ID of the house that was sold
# >
# > Data type: Int64
#
# **date**:
# > Description: Date of the house sale
# >
# > Data type: Object
#
# **price**:
# > Description: Price the house was sold as
# >
# > Data type: Object

# %% [markdown]
# ### Step 5: Create Copies of DataFrames to Start Cleaning Process

# %%
###### TO DO ######

# create a copy of house_data

home_df = houses_df.copy()

# create a copy of sales_data

sales_df = house_sales_df.copy()

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was copied succussfully
home_df.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was copied succussfully
sales_df.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# ## Part 2: Assess Data and Create Data Cleaning Plan

# %% [markdown]
# ### Step 1: Check Column Names, Casing, Spelling, Etc.

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# 1) Need to drop Unnamed columns in both dataframes
# 2) Rename ID section to house_id 
# 3) Rename, in houses dataframe, the columns with snake_casing where necessary and also lowercase
# 4) Rename DATE and Price in sales dataframe to data/price

# %% [markdown]
# ### Step 2: Validate Data Types

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Q: Do any of the data types in the dataframe need to be changed?

# %% [markdown]
# A: #### TO DO #####
#
#  - In home_df, ID and Zipcode will need to be changed to a Obj instead of Int64/Float64
#  - In sales_df, Date needs to be changed to datetime format
#  - In sales_df, Price needs to be changed to Float64

# %% [markdown]
# ### Step 3: Detect Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
home_df.isna().sum()
#sales_df.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Bedrooms             0
# Bathrooms            2
# SQFT living          0
# SQFT lot             2
# Floors               0
# Waterfront?          8
# View                 2
# House Condition      6
# Grade                2
# SQFT above           1
# SQFT basement        0
# Year Built           1
# Year Renovated     337
# Zipcode              3
# Lat                  1
# Long                 1
# SQFT living 15       0
# SQFT lot 15          0
# dtype: int64

# %% [markdown]
# Q: Which variables/columns have missing values?

# %% [markdown]
# A: ##### TO DO #####
#
#  - Bathrooms
#  - SQFT Lot
#  - Waterfront
#  - View
#  - House Condition
#  - Grade
#  - SQFT Above
#  - Year Built
#  - Year Renovated
#  - Zipcode
#  - Lat
#  - Long
#  - Price

# %% [markdown]
# ### Step 4: Detect Outliers

# %%
######################### TO DO ###################################

import seaborn as sns

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

sns.boxplot(data=home_df['Bedrooms'])
# Out:
# <Axes: >

# %%
home_df['Bedrooms'].describe()
# Out:
# count    21613.000000
# mean         3.372091
# std          0.947533
# min          0.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: Bedrooms, dtype: float64

# %%
sns.boxplot(data=home_df['Bathrooms'])
# Out:
# <Axes: >

# %%
home_df['Bathrooms'].describe()
# Out:
# count    21611.000000
# mean         2.115173
# std          0.772019
# min          0.000000
# 25%          1.750000
# 50%          2.250000
# 75%          2.500000
# max         10.000000
# Name: Bathrooms, dtype: float64

# %%
sns.boxplot(data=home_df['SQFT living'])
# Out:
# <Axes: >

# %%
home_df['SQFT living'].describe()
# Out:
# count    21613.000000
# mean      2079.899736
# std        918.440897
# min        290.000000
# 25%       1427.000000
# 50%       1910.000000
# 75%       2550.000000
# max      13540.000000
# Name: SQFT living, dtype: float64

# %%
sns.boxplot(data=home_df['SQFT lot'])
# Out:
# <Axes: >

# %%
home_df['SQFT lot'].describe()
# Out:
# count    2.161100e+04
# mean     1.510388e+04
# std      4.141929e+04
# min      5.200000e+02
# 25%      5.040000e+03
# 50%      7.618000e+03
# 75%      1.068750e+04
# max      1.651359e+06
# Name: SQFT lot, dtype: float64

# %%
sns.boxplot(data=home_df['Floors'])
# Out:
# <Axes: >

# %%
home_df['Floors'].describe()
# Out:
# count    21613.000000
# mean         1.494309
# std          0.539989
# min          1.000000
# 25%          1.000000
# 50%          1.500000
# 75%          2.000000
# max          3.500000
# Name: Floors, dtype: float64

# %%
sns.boxplot(data=home_df['Grade'])
# Out:
# <Axes: >

# %%
home_df['Grade'].describe()
# Out:
# count    21611.000000
# mean         7.656795
# std          1.175475
# min          1.000000
# 25%          7.000000
# 50%          7.000000
# 75%          8.000000
# max         13.000000
# Name: Grade, dtype: float64

# %%
sns.boxplot(data=home_df['SQFT above'])
# Out:
# <Axes: >

# %%
home_df['SQFT above'].describe()
# Out:
# count    21612.000000
# mean      1788.861281
# std        831.369379
# min        290.000000
# 25%       1190.000000
# 50%       1560.000000
# 75%       2210.000000
# max      12542.000000
# Name: SQFT above, dtype: float64

# %%
sns.boxplot(data=home_df['SQFT basement'])
# Out:
# <Axes: >

# %%
home_df['SQFT basement'].describe()
# Out:
# count    21613.000000
# mean       291.509045
# std        442.575043
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        560.000000
# max       4820.000000
# Name: SQFT basement, dtype: float64

# %%
sns.boxplot(data=home_df['Year Built'])
# Out:
# <Axes: >

# %%
home_df['Year Built'].describe()
# Out:
# count    21612.000000
# mean      1970.958079
# std         30.108306
# min       1000.000000
# 25%       1951.000000
# 50%       1975.000000
# 75%       1997.000000
# max       2050.000000
# Name: Year Built, dtype: float64

# %%
sns.boxplot(data=home_df['Year Renovated'])
# Out:
# <Axes: >

# %%
home_df['Year Renovated'].describe()
# Out:
# count    21276.000000
# mean        85.645422
# std        404.495380
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       2015.000000
# Name: Year Renovated, dtype: float64

# %%
sns.boxplot(data=home_df['Zipcode'])
# Out:
# <Axes: >

# %%
home_df['Zipcode'].describe()
# Out:
# count    21610.000000
# mean     98077.946830
# std         53.504492
# min      98001.000000
# 25%      98033.000000
# 50%      98065.000000
# 75%      98118.000000
# max      98199.000000
# Name: Zipcode, dtype: float64

# %%
sns.boxplot(data=home_df['Lat'])
# Out:
# <Axes: >

# %%
home_df['Lat'].describe()
# Out:
# count    21612.000000
# mean        47.560043
# std          0.138560
# min         47.155900
# 25%         47.470975
# 50%         47.571800
# 75%         47.678000
# max         47.777600
# Name: Lat, dtype: float64

# %%
sns.boxplot(data=home_df['Long'])
# Out:
# <Axes: >

# %%
home_df['Long'].describe()
# Out:
# count    21612.000000
# mean      -122.213894
# std          0.140831
# min       -122.519000
# 25%       -122.328000
# 50%       -122.230000
# 75%       -122.125000
# max       -121.315000
# Name: Long, dtype: float64

# %%
sns.boxplot(data=home_df['SQFT living 15'])
# Out:
# <Axes: >

# %%
home_df['SQFT living 15'].describe()
# Out:
# count    21613.000000
# mean      1986.552492
# std        685.391304
# min        399.000000
# 25%       1490.000000
# 50%       1840.000000
# 75%       2360.000000
# max       6210.000000
# Name: SQFT living 15, dtype: float64

# %%
sns.boxplot(data=home_df['SQFT lot 15'])
# Out:
# <Axes: >

# %%
home_df['SQFT lot 15'].describe()
# Out:
# count    2.161300e+04
# mean     1.343592e+04
# std      1.018656e+05
# min      6.510000e+02
# 25%      5.100000e+03
# 50%      7.620000e+03
# 75%      1.008300e+04
# max      1.444040e+07
# Name: SQFT lot 15, dtype: float64

# %%
### DEFINE ###
# Change price from str/obj to int

### CLEAN ### 
sales_df.Price = sales_df.Price.str.replace('$', '', regex=True)
sales_df.Price = sales_df.Price.str.replace(',', '', regex=True).astype(float)

### TEST ###
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 675.5+ KB

# %%
sns.boxplot(data=sales_df['Price'])
# Out:
# <Axes: >

# %%
sales_df['Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.400546e+05
# std      3.671266e+05
# min      3.209000e+03
# 25%      3.215000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Price, dtype: float64

# %% [markdown]
# Q: Which variables/columns have outliers?

# %% [markdown]
# A: ##### TO DO #####
#
#  - Bedrooms
#  - Bathrooms
#  - SQFT living
#  - SQFT lot
#  - SQFT above
#  - SQFT basement
#  - Year Built
#  - Year Renovated
#  - SQFT living 15
#  - SQFT lot 15

# %% [markdown]
# ### Step 5: Write Data Cleaning Plan

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# #### Data Cleaning Plan:
#
# ####### TO DO #######
#
# - Drop columns Unnamed in both dataframes
# - Rename columns with lowercase and snakecase where it applies
# - Rename DATE and Price to lowercase
# - Change data types of ID and Zipcode from Int/float to Obj
# - Change data type of Date to datetime
# - Change data type of price to Obj
#
# - Address missing values from earlier section
#
# - Take away outliers after deep dive into data is done

# %% [markdown]
# ## Part 3: Execute Data Cleaning Plan Using DEFINE / CLEAN / TEST Approach

# %% [markdown]
# ### Step 1: Understand DEFINE / CLEAN / TEST Approach

# %% [markdown]
# Refer to project instructions for an explanation of this step. You can copy and past the template in the cell below to use in each step of Part 3 as you are treating the issues you found in the data.

# %%
### DEFINE ###
#Drop columns Unnamed in both dataframes

### CLEAN ### 

home_df.drop(columns=['Unnamed: 0'], inplace=True)

### TEST ###

home_df
# Out:
#                ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0      7129300520         3       1.00         1180    5650.0     1.0
# 1      6414100192         3       2.25         2570    7242.0     2.0
# 2      5631500400         2       1.00          770   10000.0     1.0
# 3      2487200875         4       3.00         1960    5000.0     1.0
# 4      1954400510         3       2.00         1680    8080.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21608   263000018         3       2.50         1530    1131.0     3.0
# 21609  6600060120         4       2.50         2310    5813.0     2.0
# 21610  1523300141         2       0.75         1020    1350.0     2.0
# 21611   291310100         3       2.50         1600    2388.0     2.0
# 21612  1523300157         2       0.75         1020    1076.0     2.0
#
#       Waterfront?       View  House Condition  Grade  SQFT above  \
# ...

# %%
### DEFINE ###
#Drop columns Unnamed in both dataframes

### CLEAN ### 
sales_df.drop(columns=['Unnamed: 0'], inplace=True)

### TEST ###
sales_df
# Out:
#                Id             DATE     Price
# 0      7129300520  20141013T000000  221900.0
# 1      6414100192  20141209T000000  538000.0
# 2      5631500400  20150225T000000  180000.0
# 3      2487200875  20141209T000000  604000.0
# 4      1954400510  20150218T000000  510000.0
# ...           ...              ...       ...
# 21608   263000018  20140521T000000  360000.0
# 21609  6600060120  20150223T000000  400000.0
# 21610  1523300141  20140623T000000  402101.0
# 21611   291310100  20150116T000000  400000.0
# 21612  1523300157  20141015T000000  325000.0
#
# [21613 rows x 3 columns]

# %% [markdown]
# ### Step 2: Treat Names / Casing / Spelling Issues

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
### DEFINE ###
# make all columns lowercase in home_df

### CLEAN ### 
home_df.columns = home_df.columns.str.lower()

### TEST ###
home_df.head()
# Out:
#            id  bedrooms  bathrooms  sqft living  sqft lot  floors waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         view  house condition  grade  sqft above  sqft basement  year built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
### DEFINE ###
# make all columns lowercase in sales_df

### CLEAN ### 
sales_df.columns = sales_df.columns.str.lower()

### TEST ###
sales_df.head()
# Out:
#            id             date     price
# 0  7129300520  20141013T000000  221900.0
# 1  6414100192  20141209T000000  538000.0
# 2  5631500400  20150225T000000  180000.0
# 3  2487200875  20141209T000000  604000.0
# 4  1954400510  20150218T000000  510000.0

# %%
### DEFINE ###
# Rename waterfront to take out the '?'

### CLEAN ### 
home_df.rename(columns={"waterfront?": "waterfront"}, inplace=True)

### TEST ###
home_df.head()
# Out:
#            id  bedrooms  bathrooms  sqft living  sqft lot  floors waterfront  \
# 0  7129300520         3       1.00         1180    5650.0     1.0         No
# 1  6414100192         3       2.25         2570    7242.0     2.0         No
# 2  5631500400         2       1.00          770   10000.0     1.0         No
# 3  2487200875         4       3.00         1960    5000.0     1.0         No
# 4  1954400510         3       2.00         1680    8080.0     1.0         No
#
#         view  house condition  grade  sqft above  sqft basement  year built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
### DEFINE ###
#rename all columns with snakecase

### CLEAN ### 

column_list = home_df.columns.to_list()
new_columns = []

for column in column_list:
    column = column.replace(" ", "_")
        
    new_columns.append(column)

home_df.columns = new_columns

### TEST ###
home_df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180    5650.0     1.0
# 1      6414100192         3       2.25         2570    7242.0     2.0
# 2      5631500400         2       1.00          770   10000.0     1.0
# 3      2487200875         4       3.00         1960    5000.0     1.0
# 4      1954400510         3       2.00         1680    8080.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21608   263000018         3       2.50         1530    1131.0     3.0
# 21609  6600060120         4       2.50         2310    5813.0     2.0
# 21610  1523300141         2       0.75         1020    1350.0     2.0
# 21611   291310100         3       2.50         1600    2388.0     2.0
# 21612  1523300157         2       0.75         1020    1076.0     2.0
#
#       waterfront       view  house_condition  grade  sqft_above  \
# ...

# %%
### DEFINE ###
# Change ID of home_df from int to str/obj

### CLEAN ### 

home_df.id = home_df.id.astype(str)

### TEST ###
home_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  object
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  year_renovated   21276 non-null  float64
#  14  zipcode          21610 non-null  float64
#  15  lat              21612 non-null  float64
# ...

# %%
### DEFINE ###
# change ID from sale_df from int to str/obj

### CLEAN ### 

sales_df.id = sales_df.id.astype(str)

### TEST ###
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21613 non-null  object
#  1   date    21613 non-null  object
#  2   price   21609 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 506.7+ KB

# %%
### DEFINE ###
# Change zipcode in home_df from int to str/obj

### CLEAN ### 

home_df.zipcode = home_df.zipcode.astype(str)

### TEST ###
home_df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180    5650.0     1.0
# 1      6414100192         3       2.25         2570    7242.0     2.0
# 2      5631500400         2       1.00          770   10000.0     1.0
# 3      2487200875         4       3.00         1960    5000.0     1.0
# 4      1954400510         3       2.00         1680    8080.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21608   263000018         3       2.50         1530    1131.0     3.0
# 21609  6600060120         4       2.50         2310    5813.0     2.0
# 21610  1523300141         2       0.75         1020    1350.0     2.0
# 21611   291310100         3       2.50         1600    2388.0     2.0
# 21612  1523300157         2       0.75         1020    1076.0     2.0
#
#       waterfront       view  house_condition  grade  sqft_above  \
# ...

# %%
### DEFINE ####

# Converting the date to datetime format in the sales_df

### CLEAN ###
sales_df['date'] = sales_df['date'].str.replace('T000000', '') 

sales_df['date'] = pd.to_datetime(sales_df['date'], format='%Y%m%d')

### TEST ###
sales_df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %% [markdown]
# ### Step 3: Treat Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
home_df.isna().sum()
# Out:
# id                   0
# bedrooms             0
# bathrooms            2
# sqft_living          0
# sqft_lot             2
# floors               0
# waterfront           8
# view                 2
# house_condition      6
# grade                2
# sqft_above           1
# sqft_basement        0
# year_built           1
# year_renovated     337
# zipcode              0
# lat                  1
# long                 1
# sqft_living_15       0
# sqft_lot_15          0
# dtype: int64

# %%
sales_df.isna().sum()
# Out:
# id       0
# date     0
# price    4
# dtype: int64

# %%
### DEFINE ###
# Removing year renovated due to the amount of missing values and the data wouldn't be make sense to find the mean for it

### CLEAN ### 
home_df.drop(columns=['year_renovated'], inplace=True)

### TEST ###
home_df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180    5650.0     1.0
# 1      6414100192         3       2.25         2570    7242.0     2.0
# 2      5631500400         2       1.00          770   10000.0     1.0
# 3      2487200875         4       3.00         1960    5000.0     1.0
# 4      1954400510         3       2.00         1680    8080.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21608   263000018         3       2.50         1530    1131.0     3.0
# 21609  6600060120         4       2.50         2310    5813.0     2.0
# 21610  1523300141         2       0.75         1020    1350.0     2.0
# 21611   291310100         3       2.50         1600    2388.0     2.0
# 21612  1523300157         2       0.75         1020    1076.0     2.0
#
#       waterfront       view  house_condition  grade  sqft_above  \
# ...

# %%
### DEFINE ###
#Drop the one lat/long row since that row can't be placed with mean/mode methods

### CLEAN ### 
home_df.drop(home_df.index[17848], inplace=True)

### TEST ###

# %%
home_df[home_df.isna().any(axis=1)]
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 10     1736800520         3        NaN         3560    9796.0     1.0
# 26     1794500383         3        NaN         2450    2691.0     2.0
# 88     1332700270         2       2.25         1610    2040.0     2.0
# 146     809001525         4       1.00         2550    4000.0     2.0
# 4864   5272200005         2       1.00         1160    6911.0     1.0
# 5103   2877102651         4       2.00         2300    3400.0     1.5
# 5111   8651510020         3       2.25         2100       NaN     2.0
# 5120    723049132         2       1.00         1500    8015.0     1.0
# 19848  4100500070         5       4.50         4590   14685.0     2.0
# 19858  2524069078         4       4.00         7850       NaN     2.0
# 19870   710600160         4       3.50         2650    3474.0     2.0
# 19944  2423069039         3       2.50         2500   51836.0     1.0
# ...

# %%
### DEFINE ###
#Drop the one year_built row that has a missing value because it can't be placed with mean/mode methods

### CLEAN ### 
home_df.drop(home_df.index[-3], inplace=True)

# %%
home_df[home_df.isna().any(axis=1)]
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 10     1736800520         3        NaN         3560    9796.0     1.0
# 26     1794500383         3        NaN         2450    2691.0     2.0
# 88     1332700270         2       2.25         1610    2040.0     2.0
# 146     809001525         4       1.00         2550    4000.0     2.0
# 4864   5272200005         2       1.00         1160    6911.0     1.0
# 5103   2877102651         4       2.00         2300    3400.0     1.5
# 5111   8651510020         3       2.25         2100       NaN     2.0
# 5120    723049132         2       1.00         1500    8015.0     1.0
# 19848  4100500070         5       4.50         4590   14685.0     2.0
# 19858  2524069078         4       4.00         7850       NaN     2.0
# 19870   710600160         4       3.50         2650    3474.0     2.0
# 19944  2423069039         3       2.50         2500   51836.0     1.0
# ...

# %%
### DEFINE ###
# Place the mean of bathrooms for the 2 missing values

### CLEAN ### 
home_df.bathrooms = home_df.bathrooms.fillna(home_df.bathrooms.mean())

### TEST ###
home_df.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           2
# floors             0
# waterfront         8
# view               2
# house_condition    6
# grade              2
# sqft_above         1
# sqft_basement      0
# year_built         0
# zipcode            0
# lat                0
# long               0
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ###
# Place the mean of sqft_lot for the 2 missing values. These two values can be placed because we can just take
#avergae size of the lots within the dataset.

### CLEAN ### 
home_df.sqft_lot = home_df.sqft_lot.fillna(home_df.sqft_lot.mean())

### TEST ###
home_df.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# waterfront         8
# view               2
# house_condition    6
# grade              2
# sqft_above         1
# sqft_basement      0
# year_built         0
# zipcode            0
# lat                0
# long               0
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ###
#Place the mean value for the 2 missing grade columns

### CLEAN ### 
home_df.grade = home_df.grade.fillna(home_df.grade.mean())

### TEST ###
home_df.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# waterfront         8
# view               2
# house_condition    6
# grade              0
# sqft_above         1
# sqft_basement      0
# year_built         0
# zipcode            0
# lat                0
# long               0
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ###
#Place the mean value for the 1 missing value in sqft_above since that can be averaged out with the 
#info we have in this dataset

### CLEAN ### 
home_df.sqft_above = home_df.sqft_above.fillna(home_df.sqft_above.mean())

### TEST ###
home_df.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# waterfront         8
# view               2
# house_condition    6
# grade              0
# sqft_above         0
# sqft_basement      0
# year_built         0
# zipcode            0
# lat                0
# long               0
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
home_df[home_df.isna().any(axis=1)]
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 88     1332700270         2       2.25         1610    2040.0     2.0
# 146     809001525         4       1.00         2550    4000.0     2.0
# 4864   5272200005         2       1.00         1160    6911.0     1.0
# 5103   2877102651         4       2.00         2300    3400.0     1.5
# 5120    723049132         2       1.00         1500    8015.0     1.0
# 19848  4100500070         5       4.50         4590   14685.0     2.0
# 19870   710600160         4       3.50         2650    3474.0     2.0
# 19944  2423069039         3       2.50         2500   51836.0     1.0
# 19993  6371000148         2       1.50         1130    1340.0     2.0
# 20029  7228500037         2       1.50         1190    1361.0     2.0
# 20077  1070000110         4       2.50         2830    5932.0     2.0
# 20143  1563102965         4       3.50         3130    5000.0     3.0
# ...

# %%
### DEFINE ###
#Place the mode of house_condition for the 6 missing values

### CLEAN ### 
condition = home_df.house_condition.mode()
home_df.house_condition.fillna(value=condition[0], inplace=True)
### TEST ###
home_df.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# waterfront         8
# view               2
# house_condition    0
# grade              0
# sqft_above         0
# sqft_basement      0
# year_built         0
# zipcode            0
# lat                0
# long               0
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ###
#Place the mode of waterfront column for the missing 8 values

### CLEAN ### 
water = home_df.waterfront.mode()
home_df.waterfront.fillna(value=water[0], inplace=True)

### TEST ###
home_df.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# waterfront         0
# view               2
# house_condition    0
# grade              0
# sqft_above         0
# sqft_basement      0
# year_built         0
# zipcode            0
# lat                0
# long               0
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ###
# Place the mode of the view for the 2 missing values

### CLEAN ### 
home_view = home_df.view.mode()
home_df.view.fillna(value=home_view[0], inplace=True)
 
### TEST ###
home_df.isna().sum()
# Out:
# id                 0
# bedrooms           0
# bathrooms          0
# sqft_living        0
# sqft_lot           0
# floors             0
# waterfront         0
# view               0
# house_condition    0
# grade              0
# sqft_above         0
# sqft_basement      0
# year_built         0
# zipcode            0
# lat                0
# long               0
# sqft_living_15     0
# sqft_lot_15        0
# dtype: int64

# %%
### DEFINE ###
#Drop the missing prices from the sales_df since that data can't be averaged out

### CLEAN ### 
sales_df.dropna(axis=0, how='any', inplace=True)

### TEST ###
sales_df.isna().sum()
# Out:
# id       0
# date     0
# price    0
# dtype: int64

# %% [markdown]
# ### Step 4: Treat Outliers

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
from scipy.stats import zscore

# %%
home_df['bedrooms_zscore'] = zscore(home_df['bedrooms'])

# %%
home_df['bathrooms_zscore'] = zscore(home_df['bathrooms'])

# %%
home_df['sqftLiv_zscore'] = zscore(home_df['sqft_living'])

# %%
home_df['sqftLot_zscore'] = zscore(home_df['sqft_lot'])

# %%
home_df['sqftAb_zscore'] = zscore(home_df['sqft_above'])

# %%
home_df['sqftBase_zscore'] = zscore(home_df['sqft_basement'])

# %%
home_df['yearB_zscore'] = zscore(home_df['year_built'])

# %%
home_df['sqftLiv15_zscore'] = zscore(home_df['sqft_living_15'])

# %%
home_df['sqftLot15_zscore'] = zscore(home_df['sqft_lot_15'])

# %%
sales_df['price_zscore'] = zscore(sales_df['price'])

# %%
home_df.query('bedrooms_zscore > 3 or bedrooms_zscore < -3')[['bedrooms', 'bedrooms_zscore']]
# Out:
#        bedrooms  bedrooms_zscore
# 16           30        28.103094
# 556           7         3.828822
# 875           0        -3.559001
# 1135          7         3.828822
# 1241          7         3.828822
# ...         ...              ...
# 18975         7         3.828822
# 19254        10         6.995031
# 19302         8         4.884225
# 19327         7         3.828822
# 19452         0        -3.559001
#
# [76 rows x 2 columns]

# %%
### DEFINE ###
# Taking away the 76 rows of outliers since theres more than enough data to still give a good visualization

### CLEAN ### 

home_df = home_df.query('bedrooms_zscore < 3 and bedrooms_zscore > -3').copy()

### TEST ###
home_df.query('bedrooms_zscore > 3 or bedrooms_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscore, sqftLiv_zscore, sqftLot_zscore, sqftAb_zscore, sqftBase_zscore, yearB_zscore, sqftLiv15_zscore, sqftLot15_zscore]
# Index: []
#
# [0 rows x 27 columns]

# %%
home_df.query('bathrooms_zscore > 3 or bathrooms_zscore < -3')[['bathrooms', 'bathrooms_zscore']]
# Out:
#        bathrooms  bathrooms_zscore
# 5           4.50          3.089303
# 44         10.00         10.214169
# 270         4.75          3.413161
# 300         5.00          3.737018
# 450         4.50          3.089303
# ...          ...               ...
# 21344       6.00          5.032449
# 21494       4.50          3.089303
# 21506       6.50          5.680164
# 21551       4.50          3.089303
# 21576       4.50          3.089303
#
# [173 rows x 2 columns]

# %%
### DEFINE ###
# Dropping the outliers for the bathrooms since the entire dataset is larger than the amount that is present with
# outliers.

### CLEAN ### 

home_df = home_df.query('bathrooms_zscore < 3 and bathrooms_zscore > -3').copy()

### TEST ###

home_df.query('bathrooms_zscore > 3 or bathrooms_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, house_condition, grade, sqft_above, sqft_basement, year_built, zipcode, lat, long, sqft_living_15, sqft_lot_15, bedrooms_zscore, bathrooms_zscore, sqftLiv_zscore, sqftLot_zscore, sqftAb_zscore, sqftBase_zscore, yearB_zscore, sqftLiv15_zscore, sqftLot15_zscore]
# Index: []
#
# [0 rows x 27 columns]

# %%
home_df.query('sqftLiv_zscore > 3 or sqftLiv_zscore < -3')[['sqft_living', 'sqftLiv_zscore']].tail(60)
# Out:
#        sqft_living  sqftLiv_zscore
# 14308         5290        3.495167
# 14419         5020        3.201187
# 14685         4930        3.103194
# 14774         5470        3.691153
# 15108         4980        3.157634
# 15347         5010        3.190299
# 15482         7000        5.357038
# 15560         5600        3.832699
# 15567         6030        4.300889
# 15668         5170        3.364509
# 15848         5930        4.192008
# 16302         5550        3.778258
# 16430         5860        4.115791
# 16614         5210        3.408061
# 16720         5110        3.299180
# 16729         5960        4.224672
# 16888         5610        3.843587
# 17288         5150        3.342733
# 17401         4960        3.135858
# 17558         5480        3.702041
# 17600         5040        3.222963
# 17647         5120        3.310068
# 17960         4920        3.092305
# 18101         4860        3.026977
# 18206         5570        3.800034
# 18266         4960        3.135858
# ...

# %%
### DEFINE ###
# I plan on keeping the outliers for the SQFT Living because there seems to be enough other correlation in the 
# group (based on the above dataframe and earlier boxplot graph) that is considered outliers. 
# While there are an even smaller number of further outliers, 
# theres enough grouping in the closer outlier group that falls between 4-5 z-score

# %%
home_df.query('sqftLot_zscore > 3 or sqftLot_zscore < -3')[['sqft_lot', 'sqftLot_zscore']]
# Out:
#        sqft_lot  sqftLot_zscore
# 145    315374.0        7.249691
# 199    155073.0        3.379388
# 238    221284.0        4.977985
# 380    209959.0        4.704554
# 411    143947.0        3.110762
# ...         ...             ...
# 21090  151588.0        3.295246
# 21325  384634.0        8.921903
# 21351  276170.0        6.303151
# 21431  159430.0        3.484583
# 21548  184231.0        4.083378
#
# [334 rows x 2 columns]

# %%
### DEFINE ###
# Same as above with being enough correlation in the outliers, the other information, that is important to note, is that
# while the number set is very large, it falls inline with how most houses sit on smaller than acre lots which an acre
# is 43,560 sqft.

# %%
home_df.query('sqftAb_zscore > 3 or sqftAb_zscore < -3')[['sqft_above', 'sqftAb_zscore']]
# Out:
#        sqft_above  sqftAb_zscore
# 269        4750.0       3.561782
# 419        6070.0       5.149561
# 484        4860.0       3.694097
# 512        4410.0       3.152809
# 532        4740.0       3.549754
# ...           ...            ...
# 21486      4620.0       3.405410
# 21525      4300.0       3.020494
# 21532      4420.0       3.164838
# 21561      4500.0       3.261067
# 21600      4470.0       3.224981
#
# [169 rows x 2 columns]

# %%
### DEFINE ###
# Keeping this outlier data due to possible correlation with houses that didn't include garages in the sqft_living column.
# With the amount present it may represent an unaccounted for variable for later data use.
# Looking at earlier datatables, it shows most of the time sqft_above = sqft_living and to keep consistent, 
# we'll keep this outlier data

# %%
home_df.query('sqftBase_zscore > 3 or sqftBase_zscore < -3')[['sqft_basement', 'sqftBase_zscore']]
# Out:
#        sqft_basement  sqftBase_zscore
# 10              1700         3.182656
# 41              1620         3.001889
# 70              1700         3.182656
# 153             1640         3.047081
# 185             2000         3.860534
# ...              ...              ...
# 20920           1870         3.566787
# 20973           2040         3.950918
# 20996           1950         3.747555
# 21321           1640         3.047081
# 21590           1800         3.408616
#
# [202 rows x 2 columns]

# %%
### DEFINE ###
# Dropping this outlier data since the the larger dataset outweights the small cluster of outliers

### CLEAN ### 
home_df = home_df.query('sqftBase_zscore < 3 and sqftBase_zscore > -3').copy()

### TEST ###
home_df.query('sqftBase_zscore > 3 or sqftBase_zscore < -3')[['sqft_basement', 'sqftBase_zscore']]
# Out:
# Empty DataFrame
# Columns: [sqft_basement, sqftBase_zscore]
# Index: []

# %%
home_df.query('yearB_zscore > 3 or yearB_zscore < -3')[['year_built', 'yearB_zscore']]
# Out:
#        year_built  yearB_zscore
# 20981      1000.0    -32.248924

# %%
### DEFINE ###
# Dropping this single row since it's just a single occurence of an outlier

### CLEAN ### 
home_df = home_df.query('year_built != 1000').copy()

### TEST ###
home_df.query('yearB_zscore > 3 or yearB_zscore < -3')[['year_built', 'yearB_zscore']]
# Out:
# Empty DataFrame
# Columns: [year_built, yearB_zscore]
# Index: []

# %%
home_df.query('sqftLiv15_zscore > 3 or sqftLiv15_zscore < -3')[['sqft_living_15', 'sqftLiv15_zscore']]
# Out:
#        sqft_living_15  sqftLiv15_zscore
# 21               4110          3.098236
# 384              4050          3.010692
# 419              4680          3.929908
# 473              4300          3.375460
# 679              4190          3.214962
# ...               ...               ...
# 21375            4620          3.842364
# 21486            4620          3.842364
# 21520            4920          4.280086
# 21525            4650          3.886136
# 21540            5790          5.549480
#
# [170 rows x 2 columns]

# %%
### DEFINE ###
# Dropping this outlier data since the the larger dataset outweights the small cluster of outliers

### CLEAN ### 
home_df = home_df.query('sqftLiv15_zscore < 3 and sqftLiv15_zscore > -3').copy()

### TEST ###
home_df.query('sqftLiv15_zscore > 3 or sqftLiv15_zscore < -3')[['sqft_living_15', 'sqftLiv15_zscore']]
# Out:
# Empty DataFrame
# Columns: [sqft_living_15, sqftLiv15_zscore]
# Index: []

# %%
home_df.query('sqftLot15_zscore > 3 or sqftLot15_zscore < -3')[['sqft_lot_15', 'sqftLiv15_zscore']]
# Out:
#        sqft_lot_15  sqftLiv15_zscore
# 1719        425581          0.836672
# 3536        339332          0.719946
# 3801        434728         -0.228452
# 6691        411962          1.070124
# 7294        358934         -0.199270
# 8664        438213          1.040943
# 8765        326097          0.544857
# 11183       380279         -0.199270
# 11564       360000         -0.447313
# 12669       325393         -0.622401
# 12754       320890         -0.768309
# 13006       325393         -1.030942
# 13464       560617         -0.709946
# 15557       335289         -1.424892
# 15620       392040         -0.067953
# 17659       386812          0.953398
# 18524     14440400         -0.680764
# 21431       392040         -0.067953

# %%
### DEFINE ###
# Dropping this outlier data since the the larger dataset outweights the small amount of outliers

### CLEAN ### 
home_df = home_df.query('sqftLot15_zscore < 3 and sqftLot15_zscore > -3').copy()

### TEST ###
home_df.query('sqftLot15_zscore > 3 or sqftLot15_zscore < -3')[['sqft_lot_15', 'sqftLiv15_zscore']]
# Out:
# Empty DataFrame
# Columns: [sqft_lot_15, sqftLiv15_zscore]
# Index: []

# %%
sales_df.query('price_zscore > 3 or price_zscore < -3')
# Out:
#                id       date      price  price_zscore
# 21     2524049179 2014-08-26  2000000.0      3.976773
# 153    7855801670 2015-04-01  2250000.0      4.657753
# 246    2025069065 2014-09-29  2400000.0      5.066340
# 269    7960900060 2015-05-04  2900000.0      6.428300
# 282    7424700045 2015-05-13  2050000.0      4.112969
# ...           ...        ...        ...           ...
# 21514  3262300818 2015-02-27  1865000.0      3.609044
# 21530  8964800330 2015-04-07  3000000.0      6.700692
# 21540   715010530 2015-01-13  1881580.0      3.654206
# 21568   524059330 2015-01-30  1700000.0      3.159597
# 21576  9253900271 2015-01-07  3567000.0      8.245154
#
# [406 rows x 4 columns]

# %%
### DEFINE ###
# Keeping the price outlier dataset because there's enough data along with seeing the boxplot from earlier that it could
# indicate a certain correlation with other factors such zipcodes, sqft available, etc that a deeper dive can provide
# information that's not considered at the moment

# %%
home_df = home_df.iloc[:,:18].copy()

# %%
home_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20971 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               20971 non-null  object
#  1   bedrooms         20971 non-null  int64
#  2   bathrooms        20971 non-null  float64
#  3   sqft_living      20971 non-null  int64
#  4   sqft_lot         20971 non-null  float64
#  5   floors           20971 non-null  float64
#  6   waterfront       20971 non-null  object
#  7   view             20971 non-null  object
#  8   house_condition  20971 non-null  object
#  9   grade            20971 non-null  float64
#  10  sqft_above       20971 non-null  float64
#  11  sqft_basement    20971 non-null  int64
#  12  year_built       20971 non-null  float64
#  13  zipcode          20971 non-null  object
#  14  lat              20971 non-null  float64
#  15  long             20971 non-null  float64
# ...

# %%
sales_df = sales_df.iloc[:, :-1].copy()

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      21609 non-null  object
#  1   date    21609 non-null  datetime64[ns]
#  2   price   21609 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 675.3+ KB

# %% [markdown]
# ### Step 5: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# ####### TO DO ###### - Edit this cell to add your summary and justification per project instructions.
#
# # Name/Casing/Spelling/Data Conversion:
#
# - Dropped columns Unnamed in both dataframes
# - Renamed columns with lowercase and snakecase where it applies
# - Also removed '?' from waterfront column
# - Renamed DATE and Price to lowercase
# - Changed data types of ID and Zipcode from Int/float to Obj
# - Changed data type of Date to datetime
# - Changed data type of price from an Obj to a float for outlier data view
#
# Justification:
# - Dropped the unnamed:0 because it was just a repeative columnn of the indexing
# - Changed the applicable columns to lowercase and snakecase for readability/access for later usage
# - Removed the ? from waterfront for readability and accessibility
# - Changed the data types of ID and Zipcode since they were not loaded with the correct datatypes
# - Changed the date to datetime format for accessibility
# - Changed the price from obj to a float for outlier data view
#
# # Treating Missing Values:
#
# - Took away the:
#     - years renovated because the missing data couldn’t be provided with the mean/mode
#     - the single row/instance of missing value for the lat/long columns
#     - the single row/instance of missing value for the year built column
#     - the missing price instances in the sales_df
# - provided the mean of missing values for bathrooms, sqft_lot, grade, and sqft_above columns
# - provided the mode of missing values for house_condition, waterfront, and view columns
#
# # Outliers
#
# - Home_df:
#     - Bedrooms - removed outliers outside of |3| zscore threshold
#     - Bathrooms - removed outliers outside of |3| zscore threshold
#     - Sqft living - kept this outlier data because there was enough grouping based on the boxplot to have some correlation
#     - Sqft lot - kept this outlier data because while the numbers were large, most homes sit within less than an acre.
#     - Grade - left outliers due to them being inside appropriate range (1-13)
#     - SQFT above - Kept this data due to there being a possible correlation with unaccounted garage space and to keep consistent with the sqft_living column
#     - Sqft basement - removed outliers outside of |3| zscore threshold
#     - Year Built - removed this one since it was only instance of an outlier
#     - SQFT Living 15 - removed outliers outside of |3| zscore threshold
#     - SQFT lot 15 - removed outliers outside of |3| zscore threshold
#
# - Sales_df:
#     - Price - kept this outlier data since based on the boxplot there could be other factors for a deeper dive on the cluster of data

# %% [markdown]
# ## Part 4: Re-Express Categorical Variables

# %% [markdown]
# ### Step 1: Determine Which Variables Need to Be Re-Expressed

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# List categorical variables which need to be re-expressed here:
#
# - waterfront
# - view
# - house_condition

# %% [markdown]
# ### Step 2: Choose Method to Re-Express Variables

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to re-express each variable and why.
#
# - waterfront: will replace the 'No/Yes' values with simple 0 or 1 (no/yes)
# - view: similar format with waterfront, replaces the categories with a numbered scale
# - house_condition: replace categories with a numbered scale

# %% [markdown]
# ### Step 3: Perform Transformation

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
home_df['waterfront'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
home_df['view'].unique()
# Out:
# array(['Very Poor', 'Good', 'Neutral', 'Great', 'Poor'], dtype=object)

# %%
home_df['house_condition'].unique()
# Out:
# array(['OK Condition', 'Great Condition', 'Good Condition',
#        'Very Bad Condition', 'Bad Condition'], dtype=object)

# %%
home_df['waterfront'] = home_df['waterfront'].replace({'Yes':1, "No":0})

# %%
home_df['view'] = home_df['view'].replace({'Very Poor':1, 'Poor':2, 'Neutral':3, 'Good':4, 'Great':5})

# %%
home_df['house_condition'] = home_df['house_condition'].replace({'Very Bad Condition':1, 'Bad Condition':2, 'OK Condition':3, 'Good Condition':4, 'Great Condition':5})

# %%
home_df['waterfront'].unique()
# Out:
# array([0, 1])

# %%
home_df['view'].unique()
# Out:
# array([1, 4, 3, 5, 2])

# %%
home_df['house_condition'].unique()
# Out:
# array([3, 5, 4, 1, 2])

# %% [markdown]
# ### Step 4: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to add your summary and justification per project instructions.
#
# - Waterfront: since this column only had a Y/N to it, replacing it with a simple 1 or 0 to indicate the boolean answer.
# - View/House_Condition: since this column had a similar range of catergories, replacing them with a scale of 1-5 helped put them numerically.

# %% [markdown]
# ## Part 5: Combine Datasets into Master DataFrame

# %% [markdown]
# ### Step 1: Choose Method to Merge DataFrames into New Master DataFrame

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to merge the data and why.
#
# - Using merge() method per instructions

# %% [markdown]
# ### Step 2: Merge DataFrames

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
complete_df = sales_df.merge(home_df, on='id')

# %%
# Use .head() method to print first few rows of new master dataframe
complete_df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  house_condition  grade  sqft_above  \
# 0    5650.0     1.0           0     1                3    7.0      1180.0
# 1    7242.0     2.0           0     1                3    7.0      2170.0
# 2   10000.0     1.0           0     1                3    6.0       770.0
# 3    5000.0     1.0           0     1                5    7.0      1050.0
# 4    8080.0     1.0           0     1                3    8.0      1680.0
#
#    sqft_basement  year_built  zipcode      lat     long  sqft_living_15  \
# ...

# %% [markdown]
# ### Step 3: Save Master DataFrame to New .CSV

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
complete_df.to_csv('complete.csv', index=False)

# %% [markdown]
# ### Step 4: Push to GitHub / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.

# %% [markdown]
# ### Step 5: Record Brief Code Walkthrough / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.
